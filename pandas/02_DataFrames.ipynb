# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creating DataFrame

# %%
data = {
    'Name': ['Krunalsinh', 'Karmrajsinh', 'Raj', 'Ram'],
    'Age': ['21', '22', '24', '34'],
    'City': ["Surendranagar", 'Rajkot', 'Morbi', 'Surat'],
    'Salary': [60000, 20000, 40000, 54000]
}

df = pd.DataFrame(data)
df
# Out:
#           Name Age           City  Salary
# 0   Krunalsinh  21  Surendranagar   60000
# 1  Karmrajsinh  22         Rajkot   20000
# 2          Raj  24          Morbi   40000
# 3          Ram  34          Surat   54000

# %%
data_list = [
    ['Krunalsinh', 21, 'Surendranagar', 60000],
    ['Karmrajsinh', 22, 'Rajkot', 20000],
    ['Raj', 24, 'Morbi', 40000],
    ['Ram', 34 , 'Surat', 54000]
]
df_list = pd.DataFrame(data_list)
df_list
# Out:
#              0   1              2      3
# 0   Krunalsinh  21  Surendranagar  60000
# 1  Karmrajsinh  22         Rajkot  20000
# 2          Raj  24          Morbi  40000
# 3          Ram  34          Surat  54000

# %%
column = ["Name", "Age", "City", "Salary"]
df_list = pd.DataFrame(data_list, columns = column)
df_list
# Out:
#           Name  Age           City  Salary
# 0   Krunalsinh   21  Surendranagar   60000
# 1  Karmrajsinh   22         Rajkot   20000
# 2          Raj   24          Morbi   40000
# 3          Ram   34          Surat   54000

# %% [markdown]
# Selection and indexing of Columns

# %%
df_list
# Out:
#           Name  Age           City  Salary
# 0   Krunalsinh   21  Surendranagar   60000
# 1  Karmrajsinh   22         Rajkot   20000
# 2          Raj   24          Morbi   40000
# 3          Ram   34          Surat   54000

# %%
df_list['Name']
# Out:
# 0     Krunalsinh
# 1    Karmrajsinh
# 2            Raj
# 3            Ram
# Name: Name, dtype: object

# %%
df_list[['Name', 'City']]
# Out:
#           Name           City
# 0   Krunalsinh  Surendranagar
# 1  Karmrajsinh         Rajkot
# 2          Raj          Morbi
# 3          Ram          Surat

# %% [markdown]
# Creating a new column

# %%
df_list["Designation"] = ["Engineer", "Doctor", "Teacher", "Businessman"]

# %%
df_list
# Out:
#           Name  Age           City  Salary  Designation
# 0   Krunalsinh   21  Surendranagar   60000     Engineer
# 1  Karmrajsinh   22         Rajkot   20000       Doctor
# 2          Raj   24          Morbi   40000      Teacher
# 3          Ram   34          Surat   54000  Businessman

# %%
df_list.drop('Age', axis=1)
# Out:
#           Name           City  Salary  Designation
# 0   Krunalsinh  Surendranagar   60000     Engineer
# 1  Karmrajsinh         Rajkot   20000       Doctor
# 2          Raj          Morbi   40000      Teacher
# 3          Ram          Surat   54000  Businessman

# %%
df_list['Age'] = [20, 25, 22, 35]
df_list
# Out:
#           Name  Age           City  Salary  Designation
# 0   Krunalsinh   20  Surendranagar   60000     Engineer
# 1  Karmrajsinh   25         Rajkot   20000       Doctor
# 2          Raj   22          Morbi   40000      Teacher
# 3          Ram   35          Surat   54000  Businessman

# %% [markdown]
# Removing Columns

# %%
df_list.drop('Salary', axis=1)
# Out:
#           Name  Age  Designation
# 0   Krunalsinh   20     Engineer
# 1  Karmrajsinh   25       Doctor
# 2          Raj   22      Teacher
# 3          Ram   35  Businessman

# %%
df_list
# Out:
#           Name  Age  Salary  Designation
# 0   Krunalsinh   20   60000     Engineer
# 1  Karmrajsinh   25   20000       Doctor
# 2          Raj   22   40000      Teacher
# 3          Ram   35   54000  Businessman

# %%
df_list.drop("Age", axis=1)
# Out:
#           Name  Salary  Designation
# 0   Krunalsinh   60000     Engineer
# 1  Karmrajsinh   20000       Doctor
# 2          Raj   40000      Teacher
# 3          Ram   54000  Businessman

# %%
df_list
# Out:
#           Name  Age  Salary  Designation
# 0   Krunalsinh   20   60000     Engineer
# 1  Karmrajsinh   25   20000       Doctor
# 2          Raj   22   40000      Teacher
# 3          Ram   35   54000  Businessman

# %%
df_list.drop("Age", axis=1, inplace=True)

# %%
df_list
# Out:
#           Name  Salary  Designation
# 0   Krunalsinh   60000     Engineer
# 1  Karmrajsinh   20000       Doctor
# 2          Raj   40000      Teacher
# 3          Ram   54000  Businessman

# %% [markdown]
# Selecting Rows

# %%
df_list
# Out:
#           Name  Salary  Designation
# 0   Krunalsinh   60000     Engineer
# 1  Karmrajsinh   20000       Doctor
# 2          Raj   40000      Teacher
# 3          Ram   54000  Businessman

# %%
df_list.loc[0]
# Out:
# Name           Krunalsinh
# Salary              60000
# Designation      Engineer
# Name: 0, dtype: object

# %%
df_list.loc[[0,1]]
# Out:
#           Name  Salary Designation
# 0   Krunalsinh   60000    Engineer
# 1  Karmrajsinh   20000      Doctor

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %%
df_list
# Out:
#           Name  Salary  Designation
# 0   Krunalsinh   60000     Engineer
# 1  Karmrajsinh   20000       Doctor
# 2          Raj   40000      Teacher
# 3          Ram   54000  Businessman

# %%
df_list.loc[[0,1]][["Name","Salary"]]
# Out:
#           Name  Salary
# 0   Krunalsinh   60000
# 1  Karmrajsinh   20000

# %% [markdown]
# Conditional Selection

# %%
df_list
# Out:
#           Name  Salary  Designation
# 0   Krunalsinh   60000     Engineer
# 1  Karmrajsinh   20000       Doctor
# 2          Raj   40000      Teacher
# 3          Ram   54000  Businessman

# %%
df_list["Age"] = [21, 28, 18, 35]

# %%
df_list
# Out:
#           Name  Salary  Designation  Age
# 0   Krunalsinh   60000     Engineer   21
# 1  Karmrajsinh   20000       Doctor   28
# 2          Raj   40000      Teacher   18
# 3          Ram   54000  Businessman   35

# %%
# I only want to those people whose age above 25
df_list[df_list["Age"] > 25]
# Out:
#           Name  Salary  Designation  Age
# 1  Karmrajsinh   20000       Doctor   28
# 3          Ram   54000  Businessman   35

# %%
df_list[(df_list["Age"] > 25) & (df_list["Designation"] == "Doctor")]
# Out:
#           Name  Salary Designation  Age
# 1  Karmrajsinh   20000      Doctor   28
